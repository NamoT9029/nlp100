# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# ## 00. パタトクカシーー
# 2つの文字列「パトカー」と「タクシー」の文字を先頭から交互に連結し、文字列「パタトクカシーー」を得よ。

# %%
t0_1 = "パトカー"
t0_2 = "タクシー"
t0_3 = "".join([s + t for s, t in zip(t0_1, t0_2)])

print(t0_3)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 01. タクシー
# 文字列「パタトクカシーー」の2, 4, 6, 8文字目を取り出し、それらを連結した文字列を得よ。

# %%
t1 = t0_3[1:8:2]
print(t1)
# Out:
# タクシー

# %% [markdown]
# ## 02. 文字列の逆順
# 文字列"stressed"の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ。

# %%
t2 = "stressed"
print(t2[::-1])
# Out:
# desserts

# %% [markdown]
# ## 03. 円周率
# "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し、各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ。

# %%
t3 = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
t3 = t3.replace(",", "").replace(".", "").split()
l = [len(t) for t in t3]
print(l)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し、1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字、それ以外の単語は先頭の2文字を取り出し、取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ。

# %%
t4 = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
t4 = t4.replace(".", "").split()
head = [1, 5, 6, 7, 8, 9, 15, 16, 19]
dic = {i: t[0] if i in head else t[:2] for i, t in enumerate(t4, 1)}
print(dic)
# Out:
# {1: 'H', 2: 'He', 3: 'Li', 4: 'Be', 5: 'B', 6: 'C', 7: 'N', 8: 'O', 9: 'F', 10: 'Ne', 11: 'Na', 12: 'Mi', 13: 'Al', 14: 'Si', 15: 'P', 16: 'S', 17: 'Cl', 18: 'Ar', 19: 'K', 20: 'Ca'}

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ。この関数を用い、"I am an NLPer"という文から文字tri-gram、単語bi-gramを得よ。

# %%
def n_gram(t, n):
    return [t[i:i+n] for i in range(len(t)-n+1)]
    
t5 = "I am an NLPer"

print("文字tri-gram")
print(n_gram(t5, 3))
print("単語bi-gram")
print(n_gram(t5.split(), 2))
# Out:
# 文字tri-gram
# ['I a', ' am', 'am ', 'm a', ' an', 'an ', 'n N', ' NL', 'NLP', 'LPe', 'Per']
# 単語bi-gram
# [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %% [markdown]
# ## 06. 集合
# "paraparaparadise"と"paragraph"に含まれる文字bi-gramの集合を、それぞれ, $X$ と $Y$ として求め、$X$ と $Y$ の和集合（$X \cup Y$）、積集合（$X \cap Y$）、差集合（$X \setminus Y$）を求めよ。さらに、'se'というbi-gramがXおよびYに含まれるかどうかを調べよ。

# %%
t6_1 = "paraparaparadise"
t6_2 = "paragraph"
X = set(n_gram(t6_1, 2))
Y = set(n_gram(t6_2, 2))

print("和集合")
print(X | Y)
print("積集合")
print(X & Y)
print("差集合")
print(X - Y)

if "se" in X:
    print("Xには'se'が含まれる")
else:
    print("Xには'se'が含まれない")
if "se" in Y:
    print("Yには'se'が含まれる") 
else:
    print("Yには'se'が含まれない")
# Out:
# 和集合
# {'ap', 'is', 'di', 'se', 'ad', 'ph', 'gr', 'ra', 'ag', 'pa', 'ar'}
# 積集合
# {'ap', 'ra', 'pa', 'ar'}
# 差集合
# {'is', 'di', 'ad', 'se'}
# Xには'se'が含まれる
# Yには'se'が含まれない

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ。さらに、x=12, y="気温", z=22.4として、実行結果を確認せよ。

# %%
tmp = lambda x, y, z: f"{x}時の{y}は{z}"
print(tmp(12, "気温", 22.4))
# Out:
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を、以下の仕様で変換する関数cipherを実装せよ。
#
# * 英小文字ならば (219 - 文字コード) のASCIIコードに対応する文字に置換
# * その他の文字はそのまま出力
#
# この関数を用い、英語のメッセージを暗号化・復号化せよ。

# %%
def cipher(text):
    return "".join([chr(219-ord(t)) if t.islower() else t for t in text])

t8 = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
t8_encode = cipher(t8)
t8_decode = cipher(t8_encode)

print("平文　: " + t8)
print("暗号化: " + t8_encode)
print("復号化: " + t8_decode)
# Out:
# 平文　: Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.
# 暗号化: Hr Hv Lrvw Bvxzfhv Blilm Clfow Nlg Ocrwrav Foflirmv. Nvd Nzgrlmh Mrtsg Aohl Srtm Pvzxv Svxfirgb Cozfhv. Aigsfi Krmt Czm.
# 復号化: Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して、各単語の先頭と末尾の文字は残し、それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ。ただし、長さが４以下の単語は並び替えないこととする。適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え、その実行結果を確認せよ。

# %%
import random

def shuffle_char(text):
    text = text.split()
    res = []

    for t in text:
        if len(t) <= 4:
            res.append(t)
        else:
            tmp = list(t)[1:-1]            
            random.shuffle(tmp)
            res.append(t[0]+"".join(tmp)+t[-1])
    return " ".join(res)

t9 = "I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
print(shuffle_char(t9))
# Out:
# I codl'nut bleevie that I could aaulltcy utnadsrend what I was ridaeng : the panoehmnel pwoer of the haumn mind .
